# %%
import torch
print(torch.__version__)
# Out:
# 1.12.0

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U -r yolov5/requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12536, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 12536 (delta 49), reused 58 (delta 29), pack-reused 12448
# Receiving objects: 100% (12536/12536), 12.25 MiB | 13.15 MiB/s, done.
# Resolving deltas: 100% (8641/8641), done.
# Collecting matplotlib>=3.2.2
#   Downloading matplotlib-3.5.2-cp38-cp38-macosx_11_0_arm64.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 15.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.18.5 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 6)) (1.21.2)
# Collecting numpy>=1.18.5
#   Downloading numpy-1.23.1-cp38-cp38-macosx_11_0_arm64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 14.4 MB/s eta 0:00:0000:0100:01
# Collecting opencv-python>=4.1.1
#   Downloading opencv_python-4.6.0.66-cp37-abi3-macosx_11_0_arm64.whl (30.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.0/30.0 MB 15.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Pillow>=7.1.2 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 8)) (9.0.1)
# Collecting Pillow>=7.1.2
#   Downloading Pillow-9.2.0-cp38-cp38-macosx_11_0_arm64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 8.3 MB/s eta 0:00:00a 0:00:01m
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 9)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 10)) (2.27.1)
# Collecting requests>=2.23.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 11)) (1.8.0)
# Collecting scipy>=1.4.1
#   Downloading scipy-1.8.1-cp38-cp38-macosx_12_0_arm64.whl (28.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.6/28.6 MB 15.8 MB/s eta 0:00:0000:0100:01
# Collecting torch!=1.12.0,>=1.7.0
#   Downloading torch-1.11.0-cp38-none-macosx_11_0_arm64.whl (43.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 15.1 MB/s eta 0:00:0000:0100:01
# Collecting torchvision!=0.13.0,>=0.8.1
#   Downloading torchvision-0.12.0-cp38-cp38-macosx_11_0_arm64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm>=4.41.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 14)) (4.64.0)
# Requirement already satisfied: protobuf<4.21.3 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 15)) (3.20.1)
# Collecting protobuf<4.21.3
#   Downloading protobuf-4.21.2-cp37-abi3-macosx_10_9_universal2.whl (483 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.1/483.1 kB 8.6 MB/s eta 0:00:0000:01
# Requirement already satisfied: tensorboard>=2.4.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 18)) (2.8.0)
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 15.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=1.1.4 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 22)) (1.4.2)
# Collecting pandas>=1.1.4
#   Downloading pandas-1.4.3-cp38-cp38-macosx_11_0_arm64.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 15.8 MB/s eta 0:00:0000:010:01
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 6.6 MB/s eta 0:00:0000:01
# Requirement already satisfied: ipython in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from -r yolov5/requirements.txt (line 37)) (8.1.1)
# Collecting ipython
#   Downloading ipython-8.4.0-py3-none-any.whl (750 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 11.2 MB/s eta 0:00:00a 0:00:01
# Collecting psutil
#   Downloading psutil-5.9.1.tar.gz (479 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 479.1/479.1 kB 9.7 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting thop>=0.1.0
#   Downloading thop-0.1.1.post2207130030-py3-none-any.whl (15 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (4.32.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 10)) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 10)) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 10)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 10)) (1.26.9)
# Requirement already satisfied: typing-extensions in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from torch!=1.12.0,>=1.7.0->-r yolov5/requirements.txt (line 12)) (4.1.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (2.6.6)
# Requirement already satisfied: wheel>=0.26 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.37.1)
# Collecting protobuf<4.21.3
#   Downloading protobuf-3.19.4-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.7/162.7 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.24.3 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.42.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (2.1.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (58.0.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (3.3.7)
# Requirement already satisfied: absl-py>=0.4 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.0.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.4.6)
# Requirement already satisfied: pytz>=2020.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 22)) (2022.1)
# Requirement already satisfied: decorator in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (5.1.1)
# Requirement already satisfied: backcall in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (0.1.3)
# Requirement already satisfied: pexpect>4.3 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (2.11.2)
# Requirement already satisfied: pickleshare in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (0.7.5)
# Requirement already satisfied: traitlets>=5 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (5.1.1)
# Requirement already satisfied: appnope in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (0.1.2)
# Requirement already satisfied: stack-data in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from ipython->-r yolov5/requirements.txt (line 37)) (3.0.27)
# Requirement already satisfied: six in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from jedi>=0.16->ipython->-r yolov5/requirements.txt (line 37)) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (4.11.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from pexpect>4.3->ipython->-r yolov5/requirements.txt (line 37)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r yolov5/requirements.txt (line 37)) (0.2.5)
# Requirement already satisfied: executing in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from stack-data->ipython->-r yolov5/requirements.txt (line 37)) (0.8.3)
# Requirement already satisfied: asttokens in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from stack-data->ipython->-r yolov5/requirements.txt (line 37)) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from stack-data->ipython->-r yolov5/requirements.txt (line 37)) (0.2.2)
# Requirement already satisfied: zipp>=0.5 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/tonytu/miniconda3/envs/pytorch_m1_clone/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 18)) (3.2.0)
# Building wheels for collected packages: psutil
#   Building wheel for psutil (pyproject.toml) ... done
#   Created wheel for psutil: filename=psutil-5.9.1-cp38-cp38-macosx_11_0_arm64.whl size=240530 sha256=1cfe2f4f5d50fb44684fae59005cbf58fc92725380a09efa0967c823ab3e49c0
#   Stored in directory: /Users/tonytu/Library/Caches/pip/wheels/69/3f/b4/d3ed6919124e311eab9e7b9a264f31fd43ae8e7241d4611228
# Successfully built psutil
# Installing collected packages: torch, requests, psutil, protobuf, Pillow, numpy, torchvision, thop, scipy, pandas, opencv-python, matplotlib, seaborn, ipython, tensorboard
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.0
#     Uninstalling torch-1.12.0:
#       Successfully uninstalled torch-1.12.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.0.1
#     Uninstalling Pillow-9.0.1:
#       Successfully uninstalled Pillow-9.0.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.0
#     Uninstalling torchvision-0.13.0:
#       Successfully uninstalled torchvision-0.13.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.8.0
#     Uninstalling scipy-1.8.0:
#       Successfully uninstalled scipy-1.8.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.2
#     Uninstalling pandas-1.4.2:
#       Successfully uninstalled pandas-1.4.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.1.0
#     Uninstalling matplotlib-3.1.0:
#       Successfully uninstalled matplotlib-3.1.0
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.1.1
#     Uninstalling ipython-8.1.1:
#       Successfully uninstalled ipython-8.1.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.8.0 requires tensorboard<2.9,>=2.8, but you have tensorboard 2.9.1 which is incompatible.
# Successfully installed Pillow-9.2.0 ipython-8.4.0 matplotlib-3.5.2 numpy-1.23.1 opencv-python-4.6.0.66 pandas-1.4.3 protobuf-3.19.4 psutil-5.9.1 requests-2.28.1 scipy-1.8.1 seaborn-0.11.2 tensorboard-2.9.1 thop-0.1.1.post2207130030 torch-1.11.0 torchvision-0.12.0

# %%
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

# %%
mkdir Road_Sign_Dataset
cd Road_Sign_Dataset
# Out:
#   Input In [12]
#     mkdir Road_Sign_Dataset
#           ^
# SyntaxError: invalid syntax
